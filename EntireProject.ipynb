# %%
from azureml.core import Workspace

ws = Workspace.from_config()
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code CHC3YXBTE to authenticate.
# Interactive authentication successfully completed.
# ---------------------------------------------------------------------------
# UserErrorException                        Traceback (most recent call last)
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/authentication.py in wrapper(self, *args, **kwargs)
#     288                     module_logger.debug("{} acquired lock in {} s.".format(type(self).__name__, duration))
# --> 289                 return test_function(self, *args, **kwargs)
#     290             except Exception as e:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/azureml/core/authentication.py in _check_if_subscription_exists(self, subscription_id, subscription_id_list, tenant_id)
# ...

# %%
# Out:
# hey
